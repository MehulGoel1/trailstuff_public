# %%
import cv2
import numpy as np
from skimage.transform import resize
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.feature_extraction import image
from skimage.util.shape import view_as_blocks
from skimage.util.shape import view_as_windows
# Out:
# Using TensorFlow backend.

# %%
path='/home/ipsa/Downloads/TMAP/train/masks/r18.jpg'
img=load_img('/home/ipsa/Downloads/TMAP/train/masks/r18.jpg')
iimg=img_to_array(img)
plt.imshow(iimg/255.)

# %%
cvimg=cv2.imread(path)

# %%
d=cv2.resize(cvimg,(256,256))

# %%
d.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(d/255.)

# %%
outname='output mask name.jpg'
from PIL import Image

img = Image.open(path) # image extension *.png,*.jpg
new_width  = 256
new_height = 256
img = img.resize((new_width, new_height), Image.ANTIALIAS)
img.save(outname) # format may what u want ,*.png,*jpg,*.gif

# %%
p=load_img(outname)
darr=img_to_array(p)
darr.shape
patches = mage.extract_patches_2d(darr, (32,32))
patches.shape

# %%
p
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FF93F42EBE0>

# %%
darr=img_to_array(p)

# %%
darr.shape
# Out:
# (256, 256, 3)

# %%
patches = image.extract_patches_2d(darr, (32,32))

# %%
patches.shape
# Out:
# (50625, 32, 32, 3)

# %%
y=[]
for n in range(0,50625):
    if np.sum(patches[n]) > 0.0:
        print('hello'+str(n))
        break
    else:
        y.append(0)
# Out:
# hello2074

# %%
np.sum(patches[1])
# Out:
# 0.0
