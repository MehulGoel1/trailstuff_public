# %%
import cv2
import numpy as np
from skimage.transform import resize
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.feature_extraction import image
from skimage.util.shape import view_as_blocks
from skimage.util.shape import view_as_windows
# Out:
# Using TensorFlow backend.

# %%
img=load_img('/home/ipsa/Downloads/TMAP/train/images/r18.jpg')
iimg=img_to_array(img)
plt.imshow(iimg/255.)

# %%
m=load_img('/home/ipsa/Downloads/TMAP/train/masks/r18.jpg')
mm=img_to_array(m)
plt.imshow(mm/255.)

# %%
g=load_img('/home/ipsa/resizedR18.jpg')
gg=img_to_array(g)

# %%
B=view_as_blocks(gg,(64,64))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-3d416b8548de> in <module>
# ----> 1 B=view_as_blocks(gg,(64,64))
#
# ~/m1/lib/python3.5/site-packages/skimage/util/shape.py in view_as_blocks(arr_in, block_shape)
#      82
#      83     if block_shape.size != arr_in.ndim:
# ---> 84         raise ValueError("'block_shape' must have the same length "
#      85                          "as 'arr_in.shape'")
#      86
#
# ValueError: 'block_shape' must have the same length as 'arr_in.shape'

# %%
A = np.arange(81).reshape(9,9)

# %%
B = view_as_blocks(A, block_shape=(3,2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-4c0b6105ab46> in <module>
# ----> 1 B = view_as_blocks(A, block_shape=(3,2))
#
# ~/m1/lib/python3.5/site-packages/skimage/util/shape.py in view_as_blocks(arr_in, block_shape)
#      87     arr_shape = np.array(arr_in.shape)
#      88     if (arr_shape % block_shape).sum() != 0:
# ---> 89         raise ValueError("'block_shape' is not compatible with 'arr_in'")
#      90
#      91     # -- restride the array to build the block view
#
# ValueError: 'block_shape' is not compatible with 'arr_in'

# %%
B
# Out:
# array([[[[ 0,  1,  2],
#          [ 9, 10, 11],
#          [18, 19, 20]],
#
#         [[ 3,  4,  5],
#          [12, 13, 14],
#          [21, 22, 23]],
#
#         [[ 6,  7,  8],
#          [15, 16, 17],
#          [24, 25, 26]]],
#
#
#        [[[27, 28, 29],
#          [36, 37, 38],
#          [45, 46, 47]],
#
#         [[30, 31, 32],
#          [39, 40, 41],
#          [48, 49, 50]],
#
#         [[33, 34, 35],
#          [42, 43, 44],
#          [51, 52, 53]]],
#
#
#        [[[54, 55, 56],
#          [63, 64, 65],
#          [72, 73, 74]],
#
#         [[57, 58, 59],
#          [66, 67, 68],
#          [75, 76, 77]],
#
#         [[60, 61, 62],
#          [69, 70, 71],
#          [78, 79, 80]]]])

# %%
B.shape
# Out:
# (3, 3, 3, 3)

# %%
plt.imshow(B[0][0][0][0]/255.)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-8a38ff1f13eb> in <module>
# ----> 1 plt.imshow(B[0][0][0][0]/255.)
#
# ~/m1/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# ~/m1/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
u=(64,64)

# %%
t=(u,)*3

# %%
print(len(t))
# Out:
# 3

# %%
mm[100][400]
# Out:
# array([0., 0., 0.], dtype=float32)

# %%
mm.shape
# Out:
# (1040, 780, 3)

# %%
img_patches=image.extract_patches_2d(iimg,(4,4))

# %%
len(img_patches)
# Out:
# 805749

# %%
patches = image.extract_patches_2d(mm, (4, 4))

# %%
patches.shape
# Out:
# (805749, 4, 4, 3)

# %%
np.sum(patches[805748])
# Out:
# 0.0

# %%
len(patches)
# Out:
# 805749

# %%
y=[]
for n in range(0,805749):
    if np.sum(patches[n]) > 0.0:
        print('hello'+str(n))
        break
    else:
        y.append(0)
# Out:
# hello134796

# %%
x=[]
for n in range(0,805749):
    x.append(n)

# %%
plt.plot(x,y)

# %%
y=[0,1]

# %%
count=0
bcount=0
nbcount=0
for n in range(0,144796):
    if np.sum(patches[n]) > 0.0:
        nbcount=nbcount+1
        cv2.imwrite('patc/nonburnt/n'+str(nbcount)+'.jpg',img_patches[n])
    else:
        bcount=bcount+1
        cv2.imwrite('patc/burnt/b'+str(bcount)+'.jpg',img_patches[n])

# %%
cv2.imwrite('patc/nonburnt/b'+str(bcount)+'.jpg',img_patches[200000])
# Out:
# True

# %%
count
# Out:
# 171372

# %%
np.sum(patches[0]) == 0.0
# Out:
# True

# %%
cv2.imwrite("patc/patch1.jpg",img_patches[0])
# Out:
# False

# %%
img=

# %%
1,2,3,4,5,6,10,12,13,15,20,26,30,39,52,60,65,78,130,156,195,260,390,780

1,2,4,5,8,10,13,16,20,26,40,52,65,80,104,130,208,260,520,1040
